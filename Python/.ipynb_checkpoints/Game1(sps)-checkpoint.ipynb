# %%
import numpy as np 
import pandas as pd
import random

# %% [markdown]
# ### Stone, Paper and Scissor Game

# %%
computer = ['Stone' , 'Paper', 'Scissor']
com = random.choice([1, 2, 3])

user = int(input('Enter your choice\n 1 = Stone\n 2 = Paper\n 3 = Scissor\n'))
dict1 = {'Stone' : 1, 'Paper' : 2, 'Scissor': 3}
reversedict = {1 : 'Stone', 2 : 'Paper', 3 : 'Scissor'}

you = reversedict[user]
print(f' You choose {reversedict[dict1[you]]} and Computer choose {reversedict[com]}')

if user == com:
    print('its Draw')
elif user - com == -1 or user - com == 2:
    print('You loose')
else :
    print('You win')
# Out:
# Enter your choice
#  1 = Stone
#  2 = Paper
#  3 = Scissor
#  2
#  You choose Paper and Computer choose Scissor
# You loose

# %% [markdown]
# <details>
#     <summary>Click here for another method</summary>
#
# ```python
# elif user == 1 and com == 2:  # user - com = -1 -> loose
#     print('You loose')
# elif user == 2 and com == 1:
#     print('You win')
# elif user == 2 and com == 3:  # user - com = -1 -> loose
#     print('You loose')
# elif user == 3 and com == 2:
#     print('You win')
# elif user == 1 and com == 3:
#     print('You win')
# elif user == 3 and com == 1:  # user - com = 2 -> loose
#     print('You loose')
# else:
#     print('Invalid choice')
# ```
# </details>

# %% [markdown]
# <img src= "data:image/jpeg;base64,..." width="500">

# %%
def game1():
        try :
    
            import random
            
            computer = random.choice([1, 0, -1])
            
            user = input('Enter your choice from (s = snake | w = water | g = gun)').lower()
            
            dict = { 1 : 'snake', 0 : 'water', -1 : 'gun' }
            reversedict = {'s' : 1, 'w' : 0 , 'g' : -1}
            you = reversedict[user]
            
            print(f'Computer choose {dict[computer]} and you choose {dict[you]}')
                         
            if computer == you : 
                print('It\'s Draw!')
            elif computer - you == -1 or computer - you == 2 : 
                print('You Win!')
            else : 
                print('You Loose!')
    
        except :
            print('Please Enter Correct Choice')
        else : 
            print('Thank You For Playing')
