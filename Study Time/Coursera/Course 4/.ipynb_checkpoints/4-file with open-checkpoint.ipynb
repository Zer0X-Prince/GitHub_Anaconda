# %%
with open('this.txt', 'w') as f:
    f.write('first line\n')
    f.write('second line\n')
    f.write('third line\n')
    f.write('fourth line\n')

# %%
print(f.mode)
print(f.name)
# Out:
# w
# this.txt

# %%
with open('this.txt', 'r') as f:
    f3 =f.readline(4)
print(f3)
# Out:
# firs

# %%
with open('this.txt', 'r') as f:
    f4 =f.read()
print(f4)
# Out:
# first line
# second line
# third line
# fourth line

# %%
with open('this.txt', 'r')as f:
    f3 =f.readlines()
print(f3)
# Out:
# ['first line\n', 'second line\n', 'third line\n', 'fourth line\n']

# %%
with open('this.txt', 'r')as f:
    for line in f:
        print(line)
# Out:
# first line
#
# second line
#
# third line
#
# fourth line

# %%
print(type(line))
print(type(f))
print(type(f3))
# Out:
# <class 'str'>
# <class '_io.TextIOWrapper'>
# <class 'list'>

# %%
with open("this.txt","a") as file1: 
    file1.write("This is an additional line\n")
