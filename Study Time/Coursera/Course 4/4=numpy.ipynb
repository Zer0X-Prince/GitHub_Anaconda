# %%
import numpy as np

# %%
a = np.array([0,1,2,3,4])
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
print("a[0]:", a[0])
print("a[1]:", a[1])
print("a[2]:", a[2])
print("a[3]:", a[3])
print("a[4]:", a[4])
# Out:
# a[0]: 0
# a[1]: 1
# a[2]: 2
# a[3]: 3
# a[4]: 4

# %%
np.__version__
# Out:
# '2.3.5'

# %%
type(a)
# Out:
# numpy.ndarray
