# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ```python
# df = pd.read_csv(r' file path', header = None) # for json , excel, sql
# df.columns = ['a', 'b', for all column name)
# df.to_csv('file name')

# %% [markdown]
# ```python
# df.dtypes
# df.describe(inlude = 'all')
# df.info()

# %% [markdown]
# Accessesing database with python
# ```python
# from dmodule import connect
#
# # create connection object
# connection = connect(' databasename', 'username', 'pswd')
#
# #create cursor object
# cursor = connection.cursor()
#
# # run queries
# cursor.execute('select * from mytable')
# result = cursor.fetchall()
#
# # free resoures
# cursor.close()
# connection.close()
