# %% [markdown]
# # Title
# Subtitle

# %%
# !pip install numpy

# %%
# !pip install numpy

# %%
import numpy as np

# %%
n = np.array((1,2,3))
print(n)
# Out:
# [1 2 3]

# %%
print("Hello world!".upper())
print("Hello world!".lower())
print("Hello world!".title())
# Out:
# HELLO WORLD!
# hello world!
# Hello World!

# %%
111
# Out:
# 111

# %%
x = "I am Zero"
y = "You are Shadow"

# %%
f'{x} and {y}'
# Out:
# 'I am Zero and You are Shadow'
